# %% [markdown]
# ## M-Estimators for Robust Linear Modeling

# %% [markdown]
# An M-estimator minimizes the function
#
# $$Q(e_i, \rho) = \sum_i\rho(\frac{e_i}{s})$$
#
# where $\rho$ is a symmetric function of the residuals intended to reduce the influence of outliers and $s$ is an estimate of scale. The robust estimates $\hat{\beta}$ are computed by iteratively re-weighted least squares.

# %% [raw]
# We have several choices available for these weighting functions

# %%
norms = sm.robust.norms

# %%
def plot_weights(support, weights_func, xlabels, xticks):
    fig = plt.figure(figsize=(12,8))
    ax = fig.add_subplot(111)
    ax.plot(support, weights_func(support))
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels, fontsize=16)
    ax.set_ylim(-.1, 1.1)
    return ax

# %% [markdown]
# ### Andrew's Wave

# %%
help(norms.AndrewWave.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.AndrewWave method
#     Andrew's wave weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = sin(z/a)/(z/a)     for \|z\| <= a*pi
#
#         weights(z) = 0                  for \|z\| > a*pi

# %%
a = 1.339
support = np.linspace(-np.pi*a, np.pi*a, 100)
andrew = norms.AndrewWave(a=a)
plot_weights(support, andrew.weights, ['$-\pi*a$', '0', '$\pi*a$'], [-np.pi*a, 0, np.pi*a]);

# %% [markdown]
# ### Hampel's 17A

# %%
c = 8
support = np.linspace(-3*c, 3*c, 1000)
hampel = norms.Hampel(a=2., b=4., c=c)
plot_weights(support, hampel.weights, ['3*c', '0', '3*c'], [-3*c, 0, 3*c]);

# %% [markdown]
# ### Huber's t

# %%
t = 1.345
support = np.linspace(-3*t, 3*t, 1000)
huber = norms.HuberT(t=t)
plot_weights(support, huber.weights, ['-3*t', '0', '3*t'], [-3*t, 0, 3*t]);

# %% [markdown]
# ### Least Squares

# %%
support = np.linspace(-3, 3, 1000)
lst_sq = norms.LeastSquares()
plot_weights(support, lst_sq.weights, ['-3', '0', '3'], [-3, 0, 3]);

# %% [markdown]
# ### Ramsay's Ea

# %%
a = .3
support = np.linspace(-3*a, 3*a, 1000)
ramsay = norms.RamsayE(a=a)
plot_weights(support, ramsay.weights, ['-3*a', '0', '3*a'], [-3*a, 0, 3*a]);

# %% [markdown]
# ### Trimmed Mean

# %%
c = 2
support = np.linspace(-3*c, 3*c, 1000)
trimmed = norms.TrimmedMean(c=c)
plot_weights(support, trimmed.weights, ['-3*c', '0', '3*c'], [-3*c, 0, 3*c]);

# %% [markdown]
# ### Tukey's Biweight

# %%
c = 4.685
support = np.linspace(-3*c, 3*c, 1000)
tukey = norms.TukeyBiweight(c=c)
plot_weights(support, tukey.weights, ['-3*c', '0', '3*c'], [-3*c, 0, 3*c]);

# %% [markdown]
# ### Scale Estimators

# %% [raw]
# The default is MAD - Median Absolute Deviation, but another popular choice is Huber's proposal 2

# %%
np.random.seed(12345)
fat_tails = stats.t(6).rvs(40)

# %%
print fat_tails.mean(), fat_tails.std()
# Out:
# 0.0688231044811 1.34716332297

# %%
print stats.norm.fit(fat_tails)
# Out:
# (0.068823104481087458, 1.3471633229698652)

# %%
print stats.t.fit(fat_tails, f0=6)
# Out:
# (6, 0.039079792027207585, 1.0564151783954063)

# %%
huber = sm.robust.scale.Huber()
loc, scale = huber(fat_tails)
print loc, scale
# Out:
# 0.0404898433327 1.15571400476

# %%
sm.robust.stand_mad(fat_tails)
# Out:
# 1.1153350011654151

# %%
sm.robust.scale.mad(fat_tails)
# Out:
# 1.2136403757006273

# %% [markdown]
# ### Duncan's Occupational Prestige data - M-estimation for outliers

# %%
from statsmodels.graphics.api import abline_plot
from pandas.rpy import load_data
from statsmodels.formula.api import ols, rlm

# %%
prestige = load_data('Duncan', 'car')
print prestige.head(10)
# Out:
#             type  income  education  prestige
# accountant  prof      62         86        82
# pilot       prof      72         76        83
# architect   prof      75         92        90
# author      prof      55         90        76
# chemist     prof      64         86        90
# minister    prof      21         84        87
# professor   prof      64         93        93
# dentist     prof      80        100        90
# reporter      wc      67         87        52
# engineer    prof      72         86        88

# %%
fig = plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(211)
ax1.scatter(prestige.income, prestige.prestige)
ax1.set_xlabel('Income')
ax1.set_ylabel('Prestige')
xy_outlier = prestige.ix['minister'][['income','prestige']]
ax1.annotate('Minister', xy_outlier, xy_outlier+1, fontsize=16)
ax2 = fig.add_subplot(212)
ax2.scatter(prestige.education, prestige.prestige)
ax2.set_xlabel('Education')
ax2.set_ylabel('Prestige');

# %%
ols_model = ols('prestige ~ income + education', prestige).fit()
print ols_model.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prestige   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Sun, 15 Jul 2012   Prob (F-statistic):           8.65e-17
# Time:                        11:38:52   Log-Likelihood:                -178.98
# No. Observations:                  45   AIC:                             364.0
# Df Residuals:                      42   BIC:                             369.4
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -6.0647      4.272     -1.420      0.163       -14.686     2.556
# income         0.5987      0.120      5.003      0.000         0.357     0.840
# education      0.5458      0.098      5.555      0.000         0.348     0.744
# ==============================================================================
# Omnibus:                        1.279   Durbin-Watson:                   1.458
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.520
# Skew:                           0.155   Prob(JB):                        0.771
# Kurtosis:                       3.426   Cond. No.                         163.
# ==============================================================================

# %%
infl = ols_model.get_influence()
student = infl.summary_frame()['student_resid']
print student
# Out:
# accountant            0.304
# pilot                 0.341
# architect             0.072
# author                0.001
# chemist               0.827
# minister              3.135
# professor             0.768
# dentist              -0.498
# reporter             -2.397
# engineer              0.306
# undertaker           -0.187
# lawyer               -0.303
# physician             0.356
# welfare.worker       -0.411
# teacher               0.051
# conductor            -1.704
# contractor            2.044
# factory.owner         1.602
# store.manager         0.142
# banker                0.508
# bookkeeper           -0.902
# mail.carrier         -1.433
# insurance.agent      -1.931
# store.clerk          -1.760
# carpenter             1.069
# electrician           0.732
# RR.engineer           0.809
# machinist             1.887
# auto.repairman        0.523
# plumber              -0.378
# gas.stn.attendant    -0.667
# coal.miner            1.019
# streetcar.motorman   -1.104
# taxi.driver           0.023
# truck.driver         -0.129
# machine.operator      0.500
# barber                0.174
# bartender            -0.902
# shoe.shiner          -0.429
# cook                  0.127
# soda.clerk           -0.883
# watchman             -0.514
# janitor              -0.080
# policeman             0.079
# waiter               -0.476
# Name: student_resid

# %%
print student.ix[np.abs(student) > 2]
# Out:
# minister      3.135
# reporter     -2.397
# contractor    2.044
# Name: student_resid

# %%
print infl.summary_frame().ix['minister']
# Out:
# dfb_Intercept      0.145
# dfb_income        -1.221
# dfb_education      1.263
# cooks_d            0.566
# dffits             1.434
# dffits_internal    1.304
# hat_diag           0.173
# standard_resid     2.849
# student_resid      3.135
# Name: minister

# %%
print ols_model.outlier_test('sidak')
# Out:
#                     student_resid  unadj_p  sidak(p)
# accountant                  0.304    0.763     1.000
# pilot                       0.341    0.735     1.000
# architect                   0.072    0.943     1.000
# author                      0.001    0.999     1.000
# chemist                     0.827    0.413     1.000
# minister                    3.135    0.003     0.133
# professor                   0.768    0.447     1.000
# dentist                    -0.498    0.621     1.000
# reporter                   -2.397    0.021     0.618
# engineer                    0.306    0.761     1.000
# undertaker                 -0.187    0.852     1.000
# lawyer                     -0.303    0.763     1.000
# physician                   0.356    0.724     1.000
# welfare.worker             -0.411    0.683     1.000
# teacher                     0.051    0.960     1.000
# conductor                  -1.704    0.096     0.989
# contractor                  2.044    0.047     0.888
# factory.owner               1.602    0.117     0.996
# store.manager               0.142    0.887     1.000
# banker                      0.508    0.614     1.000
# bookkeeper                 -0.902    0.372     1.000
# mail.carrier               -1.433    0.159     1.000
# insurance.agent            -1.931    0.060     0.939
# store.clerk                -1.760    0.086     0.982
# carpenter                   1.069    0.291     1.000
# electrician                 0.732    0.468     1.000
# RR.engineer                 0.809    0.423     1.000
# machinist                   1.887    0.066     0.954
# auto.repairman              0.523    0.604     1.000
# plumber                    -0.378    0.707     1.000
# gas.stn.attendant          -0.667    0.509     1.000
# coal.miner                  1.019    0.314     1.000
# streetcar.motorman         -1.104    0.276     1.000
# taxi.driver                 0.023    0.982     1.000
# truck.driver               -0.129    0.898     1.000
# machine.operator            0.500    0.620     1.000
# barber                      0.174    0.863     1.000
# bartender                  -0.902    0.372     1.000
# shoe.shiner                -0.429    0.670     1.000
# cook                        0.127    0.899     1.000
# soda.clerk                 -0.883    0.382     1.000
# watchman                   -0.514    0.610     1.000
# janitor                    -0.080    0.937     1.000
# policeman                   0.079    0.938     1.000
# waiter                     -0.476    0.637     1.000

# %%
rlm_model = rlm('prestige ~ income + education', prestige).fit()
print rlm_model.summary()
# Out:
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:               prestige   No. Observations:                   45
# Model:                            RLM   Df Residuals:                       42
# Method:                          IRLS   Df Model:                            2
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Sun, 15 Jul 2012
# Time:                        11:38:53
# No. Iterations:                    18
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -7.1107      3.879     -1.833      0.067       -14.713     0.492
# income         0.7015      0.109      6.456      0.000         0.489     0.914
# education      0.4854      0.089      5.441      0.000         0.311     0.660
# ==============================================================================
#
# If the model instance has been used for another fit with different fit
# parameters, then the fit options might not be the correct ones anymore .

# %%
print rlm_model.weights
# Out:
# accountant            1.000
# pilot                 1.000
# architect             1.000
# author                1.000
# chemist               1.000
# minister              0.345
# professor             1.000
# dentist               1.000
# reporter              0.442
# engineer              1.000
# undertaker            1.000
# lawyer                1.000
# physician             1.000
# welfare.worker        1.000
# teacher               1.000
# conductor             0.538
# contractor            0.552
# factory.owner         0.706
# store.manager         1.000
# banker                1.000
# bookkeeper            1.000
# mail.carrier          0.691
# insurance.agent       0.533
# store.clerk           0.619
# carpenter             0.936
# electrician           1.000
# RR.engineer           1.000
# machinist             0.570
# auto.repairman        1.000
# plumber               1.000
# gas.stn.attendant     1.000
# coal.miner            0.964
# streetcar.motorman    0.833
# taxi.driver           1.000
# truck.driver          1.000
# machine.operator      1.000
# barber                1.000
# bartender             1.000
# shoe.shiner           1.000
# cook                  1.000
# soda.clerk            1.000
# watchman              1.000
# janitor               1.000
# policeman             1.000
# waiter                1.000

# %% [markdown]
# ### Hertzprung Russell data for Star Cluster CYG 0B1 - Leverage Points

# %% [raw]
# Data is on the luminosity and temperature of 47 stars in the direction of Cygnus.

# %%
dta = load_data('starsCYG', package='robustbase')

# %%
from matplotlib.patches import Ellipse
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, xlabel='log(Temp)', ylabel='log(Light)', title='Hertzsprung-Russell Diagram of Star Cluster CYG OB1')
ax.scatter(*dta.values.T)
# highlight outliers
e = Ellipse((3.5, 6), .2, 1, alpha=.25, color='r')
ax.add_patch(e);
ax.annotate('Red giants', xy=(3.6, 6), xytext=(3.8, 6),
            arrowprops=dict(facecolor='black', shrink=0.05, width=2),
            horizontalalignment='left', verticalalignment='bottom',
            clip_on=True, # clip to the axes bounding box
            fontsize=16,
     )
# annotate these with their index
for i,row in dta.ix[dta['log.Te'] < 3.8].iterrows():
    ax.annotate(i, row, row + .01, fontsize=14)
xlim, ylim = ax.get_xlim(), ax.get_ylim()

# %%
from IPython.display import Image
Image(filename='star_diagram.png')

# %%
y = dta['log.light']
X = sm.add_constant(dta['log.Te'], prepend=True)
ols_model = sm.OLS(y, X).fit()
abline_plot(model_results=ols_model, ax=ax)

# %%
rlm_mod = sm.RLM(y, X, sm.robust.norms.TrimmedMean(.5)).fit()
abline_plot(model_results=rlm_mod, ax=ax, color='red')

# %% [raw]
# Why? Because M-estimators are not robust to leverage points.

# %%
infl = ols_model.get_influence()
h_bar = 2*(ols_model.df_model + 1 )/ols_model.nobs
hat_diag = infl.summary_frame()['hat_diag']
hat_diag.ix[hat_diag > h_bar]
# Out:
# 11    0.194
# 20    0.194
# 30    0.198
# 34    0.194
# Name: hat_diag

# %%
print ols_model.outlier_test('sidak')
# Out:
#     student_resid  unadj_p  sidak(p)
# 1           0.431    0.669     1.000
# 2           1.522    0.135     0.999
# 3          -0.182    0.856     1.000
# 4           1.522    0.135     0.999
# 5           0.308    0.760     1.000
# 6           0.914    0.366     1.000
# 7          -1.027    0.310     1.000
# 8           0.656    0.515     1.000
# 9           0.961    0.342     1.000
# 10          0.235    0.815     1.000
# 11          0.744    0.461     1.000
# 12          0.872    0.388     1.000
# 13          0.857    0.396     1.000
# 14         -2.035    0.048     0.900
# 15         -1.375    0.176     1.000
# 16         -0.689    0.494     1.000
# 17         -2.049    0.046     0.893
# 18         -1.427    0.161     1.000
# 19         -1.576    0.122     0.998
# 20          1.065    0.293     1.000
# 21         -1.151    0.256     1.000
# 22         -1.450    0.154     1.000
# 23         -0.980    0.333     1.000
# 24         -0.156    0.877     1.000
# 25          0.065    0.948     1.000
# 26         -0.546    0.588     1.000
# 27         -0.641    0.525     1.000
# 28         -0.147    0.883     1.000
# 29         -1.187    0.242     1.000
# 30          1.389    0.172     1.000
# 31         -1.009    0.318     1.000
# 32          0.342    0.734     1.000
# 33          0.473    0.639     1.000
# 34          1.906    0.063     0.954
# 35         -1.272    0.210     1.000
# 36          1.347    0.185     1.000
# 37          0.319    0.751     1.000
# 38          0.473    0.639     1.000
# 39          0.462    0.646     1.000
# 40          1.092    0.281     1.000
# 41         -0.646    0.521     1.000
# 42          0.188    0.852     1.000
# 43          0.727    0.471     1.000
# 44          0.688    0.495     1.000
# 45          1.135    0.263     1.000
# 46          0.046    0.964     1.000
# 47         -0.834    0.409     1.000

# %% [raw]
# Let's delete that line

# %%
del ax.lines[-1]

# %%
weights = np.ones(len(X))
weights[X[X['log.Te'] < 3.8].index.values - 1] = 0
wls_model = sm.WLS(y, X, weights=weights).fit()
abline_plot(model_results=wls_model, ax=ax, color='green')

# %% [raw]
# MM estimators are good for this type of problem, unfortunately, we don't yet have these yet. It's being worked on by one of our Google Summer of Code students. We have a good excuse to look at the R cell magics in the notebook.

# %%
yy = y.values[:,None]
xx = X['log.Te'].values[:,None]

# %%
# %load_ext rmagic

# %Rpush yy xx
# %R mod <- lmrob(yy ~ xx);
# %R params <- mod$coefficients;
# %Rpull params

# %%
# %R print(mod)
# Out:
# Call:
# lmrob(formula = yy ~ xx)
#
# Coefficients:
# (Intercept)           xx
#      -4.969        2.253

# %%
print params
# Out:
# [-4.9694  2.2532]

# %%
abline_plot(intercept=params[0], slope=params[1], ax=ax, color='green')
