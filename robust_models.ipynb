# %% [markdown]
# ## M-Estimators for Robust Linear Modeling

# %% [markdown]
# An M-estimator minimizes the function
#
# $$Q(e_i, \rho) = \sum_i~\rho(\frac{e_i}{s})$$
#
# where $\rho$ is a symmetric function of the residuals intended to reduce the influence of outliers and $s$ is an estimate of scale. The robust estimates $\hat{\beta}$ are computed by iteratively re-weighted least squares.

# %% [raw]
# We have several choices available for these weighting functions

# %%
norms = sm.robust.norms

# %%
def plot_weights(support, weights_func, xlabels, xticks):
    fig = plt.figure(figsize=(12,8))
    ax = fig.add_subplot(111)
    ax.plot(support, weights_func(support))
    ax.set_xticks(xticks)
    ax.set_xticklabels(xlabels, fontsize=16)
    ax.set_ylim(-.1, 1.1)
    return ax

# %% [markdown]
# ### Andrew's Wave

# %%
help(norms.AndrewWave.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.AndrewWave method
#     Andrew's wave weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = sin(z/a)/(z/a)     for \|z\| <= a*pi
#
#         weights(z) = 0                  for \|z\| > a*pi

# %%
a = 1.339
support = np.linspace(-np.pi*a, np.pi*a, 100)
andrew = norms.AndrewWave(a=a)
plot_weights(support, andrew.weights, ['$-\pi*a$', '0', '$\pi*a$'], [-np.pi*a, 0, np.pi*a]);
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1210: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Hampel's 17A

# %%
help(norms.Hampel.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.Hampel method
#     Hampel weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = 1                            for \|z\| <= a
#
#         weights(z) = a/\|z\|                        for a < \|z\| <= b
#
#         weights(z) = a*(c - \|z\|)/(\|z\|*(c-b))      for b < \|z\| <= c
#
#         weights(z) = 0                            for \|z\| > c

# %%
c = 8
support = np.linspace(-3*c, 3*c, 1000)
hampel = norms.Hampel(a=2., b=4., c=c)
plot_weights(support, hampel.weights, ['3*c', '0', '3*c'], [-3*c, 0, 3*c]);

# %% [markdown]
# ### Huber's t

# %%
help(norms.HuberT.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.HuberT method
#     Huber's t weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = 1          for \|z\| <= t
#
#         weights(z) = t/\|z\|      for \|z\| > t

# %%
t = 1.345
support = np.linspace(-3*t, 3*t, 1000)
huber = norms.HuberT(t=t)
plot_weights(support, huber.weights, ['-3*t', '0', '3*t'], [-3*t, 0, 3*t]);

# %% [markdown]
# ### Least Squares

# %%
help(norms.LeastSquares.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.LeastSquares method
#     The least squares estimator weighting function for the IRLS algorithm.
#
#     The psi function scaled by the input z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = np.ones(z.shape)

# %%
support = np.linspace(-3, 3, 1000)
lst_sq = norms.LeastSquares()
plot_weights(support, lst_sq.weights, ['-3', '0', '3'], [-3, 0, 3]);

# %% [markdown]
# ### Ramsay's Ea

# %%
help(norms.RamsayE.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.RamsayE method
#     Ramsay's Ea weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = exp(-a*\|z\|)

# %%
a = .3
support = np.linspace(-3*a, 3*a, 1000)
ramsay = norms.RamsayE(a=a)
plot_weights(support, ramsay.weights, ['-3*a', '0', '3*a'], [-3*a, 0, 3*a]);

# %% [markdown]
# ### Trimmed Mean

# %%
help(norms.TrimmedMean.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.TrimmedMean method
#     Least trimmed mean weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         weights(z) = 1             for \|z\| <= c
#
#         weights(z) = 0             for \|z\| > c

# %%
c = 2
support = np.linspace(-3*c, 3*c, 1000)
trimmed = norms.TrimmedMean(c=c)
plot_weights(support, trimmed.weights, ['-3*c', '0', '3*c'], [-3*c, 0, 3*c]);

# %% [markdown]
# ### Tukey's Biweight

# %%
help(norms.TukeyBiweight.weights)
# Out:
# Help on method weights in module statsmodels.robust.norms:
#
# weights(self, z) unbound statsmodels.robust.norms.TukeyBiweight method
#     Tukey's biweight weighting function for the IRLS algorithm
#
#     The psi function scaled by z
#
#     Parameters
#     ----------
#     z : array-like
#         1d array
#
#     Returns
#     -------
#     weights : array
#         psi(z) = (1 - (z/c)**2)**2          for \|z\| <= R
#
#         psi(z) = 0                          for \|z\| > R

# %%
c = 4.685
support = np.linspace(-3*c, 3*c, 1000)
tukey = norms.TukeyBiweight(c=c)
plot_weights(support, tukey.weights, ['-3*c', '0', '3*c'], [-3*c, 0, 3*c]);

# %% [markdown]
# ### Scale Estimators

# %% [raw]
# Robust estimates of the location

# %%
x = np.array([1, 2, 3, 4, 500])

# %%
x.mean() # non-robust
# Out:
# 102.0

# %%
np.median(x) # robust - breakdown point 50%
# Out:
# 3.0

# %% [raw]
# Analagously for the scale

# %%
x.std() # not robust
# Out:
# 199.00251254695254

# %% [markdown]
# Median Absolute Deviation
#
# $$ median_i |X_i - median_j(X_j)|) $$

# %% [markdown]
# Standardized Median Absolute Deviation is a consistent estimator for $\hat{\sigma}$
#
# $$\hat{\sigma}=K \cdot MAD$$
#
# where $K$ depends on the distribution. For the normal distribution for example,
#
# $$K = \Phi^{-1}(.75)$$

# %%
stats.norm.ppf(.75)
# Out:
# 0.67448975019608171

# %%
print x
# Out:
# [  1   2   3   4 500]

# %%
sm.robust.scale.stand_mad(x)
# Out:
# 1.482602218505602

# %%
np.array([1,2,3,4,5.]).std()
# Out:
# 1.4142135623730951

# %% [raw]
# The default is MAD - Median Absolute Deviation, but another popular choice is Huber's proposal 2

# %%
np.random.seed(12345)
fat_tails = stats.t(6).rvs(40)

# %%
kde = sm.nonparametric.KDE(fat_tails)
kde.fit()
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.plot(kde.support, kde.density);

# %%
print fat_tails.mean(), fat_tails.std()
# Out:
# 0.0688231044811 1.34716332297

# %%
print stats.norm.fit(fat_tails)
# Out:
# (0.068823104481087458, 1.3471633229698652)

# %%
print stats.t.fit(fat_tails, f0=6)
# Out:
# (6, 0.039079792027207585, 1.0564151783954063)

# %%
huber = sm.robust.scale.Huber()
loc, scale = huber(fat_tails)
print loc, scale
# Out:
# 0.0404898433327 1.15571400476

# %%
sm.robust.stand_mad(fat_tails)
# Out:
# 1.1153350011654151

# %%
sm.robust.stand_mad(fat_tails, c=stats.t(6).ppf(.75))
# Out:
# 1.0483916565928972

# %%
sm.robust.scale.mad(fat_tails)
# Out:
# 1.2136403757006273

# %% [markdown]
# ### Duncan's Occupational Prestige data - M-estimation for outliers

# %%
from statsmodels.graphics.api import abline_plot

from statsmodels.formula.api import ols, rlm

# %%
try:
    from pandas.rpy import load_data
    prestige = load_data('Duncan', 'car')
except:
    url = 'http://eagle1.american.edu/~js2796a/Duncan.csv'
    prestige = pandas.read_csv(url, index_col=0)
    # could load stata file, but it's for Stata 8
    #from statsmodels.tools.tools import webuse
    #url = 'http://www.ats.ucla.edu/stat/stata/examples/ara/'
    #prestige = webuse('duncan', url)

# %%
print prestige.head(10)
# Out:
#             type  income  education  prestige
# accountant  prof      62         86        82
# pilot       prof      72         76        83
# architect   prof      75         92        90
# author      prof      55         90        76
# chemist     prof      64         86        90
# minister    prof      21         84        87
# professor   prof      64         93        93
# dentist     prof      80        100        90
# reporter      wc      67         87        52
# engineer    prof      72         86        88

# %%
fig = plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(211, xlabel='Income', ylabel='Prestige')
ax1.scatter(prestige.income, prestige.prestige)
xy_outlier = prestige.ix['minister'][['income','prestige']]
ax1.annotate('Minister', xy_outlier, xy_outlier+1, fontsize=16)
ax2 = fig.add_subplot(212, xlabel='Education',
                           ylabel='Prestige')
ax2.scatter(prestige.education, prestige.prestige);

# %%
ols_model = ols('prestige ~ income + education', prestige).fit()
print ols_model.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               prestige   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Tue, 17 Jul 2012   Prob (F-statistic):           8.65e-17
# Time:                        10:50:49   Log-Likelihood:                -178.98
# No. Observations:                  45   AIC:                             364.0
# Df Residuals:                      42   BIC:                             369.4
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -6.0647      4.272     -1.420      0.163       -14.686     2.556
# income         0.5987      0.120      5.003      0.000         0.357     0.840
# education      0.5458      0.098      5.555      0.000         0.348     0.744
# ==============================================================================
# Omnibus:                        1.279   Durbin-Watson:                   1.458
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.520
# Skew:                           0.155   Prob(JB):                        0.771
# Kurtosis:                       3.426   Cond. No.                         163.
# ==============================================================================

# %%
infl = ols_model.get_influence()
student = infl.summary_frame()['student_resid']
print student
# Out:
# accountant            0.304
# pilot                 0.341
# architect             0.072
# author                0.001
# chemist               0.827
# minister              3.135
# professor             0.768
# dentist              -0.498
# reporter             -2.397
# engineer              0.306
# undertaker           -0.187
# lawyer               -0.303
# physician             0.356
# welfare.worker       -0.411
# teacher               0.051
# conductor            -1.704
# contractor            2.044
# factory.owner         1.602
# store.manager         0.142
# banker                0.508
# bookkeeper           -0.902
# mail.carrier         -1.433
# insurance.agent      -1.931
# store.clerk          -1.760
# carpenter             1.069
# electrician           0.732
# RR.engineer           0.809
# machinist             1.887
# auto.repairman        0.523
# plumber              -0.378
# gas.stn.attendant    -0.667
# coal.miner            1.019
# streetcar.motorman   -1.104
# taxi.driver           0.023
# truck.driver         -0.129
# machine.operator      0.500
# barber                0.174
# bartender            -0.902
# shoe.shiner          -0.429
# cook                  0.127
# soda.clerk           -0.883
# watchman             -0.514
# janitor              -0.080
# policeman             0.079
# waiter               -0.476
# Name: student_resid

# %%
print student.ix[np.abs(student) > 2]
# Out:
# minister      3.135
# reporter     -2.397
# contractor    2.044
# Name: student_resid

# %%
print infl.summary_frame().ix['minister']
# Out:
# dfb_Intercept      0.145
# dfb_income        -1.221
# dfb_education      1.263
# cooks_d            0.566
# dffits             1.434
# dffits_internal    1.304
# hat_diag           0.173
# standard_resid     2.849
# student_resid      3.135
# Name: minister

# %%
sidak = ols_model.outlier_test('sidak')
sidak.sort('unadj_p', inplace=True)
print sidak
# Out:
#                     student_resid  unadj_p  sidak(p)
# minister                    3.135    0.003     0.133
# reporter                   -2.397    0.021     0.618
# contractor                  2.044    0.047     0.888
# insurance.agent            -1.931    0.060     0.939
# machinist                   1.887    0.066     0.954
# store.clerk                -1.760    0.086     0.982
# conductor                  -1.704    0.096     0.989
# factory.owner               1.602    0.117     0.996
# mail.carrier               -1.433    0.159     1.000
# streetcar.motorman         -1.104    0.276     1.000
# carpenter                   1.069    0.291     1.000
# coal.miner                  1.019    0.314     1.000
# bartender                  -0.902    0.372     1.000
# bookkeeper                 -0.902    0.372     1.000
# soda.clerk                 -0.883    0.382     1.000
# chemist                     0.827    0.413     1.000
# RR.engineer                 0.809    0.423     1.000
# professor                   0.768    0.447     1.000
# electrician                 0.732    0.468     1.000
# gas.stn.attendant          -0.667    0.509     1.000
# auto.repairman              0.523    0.604     1.000
# watchman                   -0.514    0.610     1.000
# banker                      0.508    0.614     1.000
# machine.operator            0.500    0.620     1.000
# dentist                    -0.498    0.621     1.000
# waiter                     -0.476    0.637     1.000
# shoe.shiner                -0.429    0.670     1.000
# welfare.worker             -0.411    0.683     1.000
# plumber                    -0.378    0.707     1.000
# physician                   0.356    0.724     1.000
# pilot                       0.341    0.735     1.000
# engineer                    0.306    0.761     1.000
# accountant                  0.304    0.763     1.000
# lawyer                     -0.303    0.763     1.000
# undertaker                 -0.187    0.852     1.000
# barber                      0.174    0.863     1.000
# store.manager               0.142    0.887     1.000
# truck.driver               -0.129    0.898     1.000
# cook                        0.127    0.899     1.000
# janitor                    -0.080    0.937     1.000
# policeman                   0.079    0.938     1.000
# architect                   0.072    0.943     1.000
# teacher                     0.051    0.960     1.000
# taxi.driver                 0.023    0.982     1.000
# author                      0.001    0.999     1.000

# %%
fdr = ols_model.outlier_test('fdr_bh')
fdr.sort('unadj_p', inplace=True)
print fdr
# Out:
#                     student_resid  unadj_p  fdr_bh(p)
# minister                    3.135    0.003      0.143
# reporter                   -2.397    0.021      0.476
# contractor                  2.044    0.047      0.596
# insurance.agent            -1.931    0.060      0.596
# machinist                   1.887    0.066      0.596
# store.clerk                -1.760    0.086      0.617
# conductor                  -1.704    0.096      0.617
# factory.owner               1.602    0.117      0.657
# mail.carrier               -1.433    0.159      0.797
# streetcar.motorman         -1.104    0.276      0.999
# carpenter                   1.069    0.291      0.999
# coal.miner                  1.019    0.314      0.999
# bartender                  -0.902    0.372      0.999
# bookkeeper                 -0.902    0.372      0.999
# soda.clerk                 -0.883    0.382      0.999
# chemist                     0.827    0.413      0.999
# RR.engineer                 0.809    0.423      0.999
# professor                   0.768    0.447      0.999
# electrician                 0.732    0.468      0.999
# gas.stn.attendant          -0.667    0.509      0.999
# auto.repairman              0.523    0.604      0.999
# watchman                   -0.514    0.610      0.999
# banker                      0.508    0.614      0.999
# machine.operator            0.500    0.620      0.999
# dentist                    -0.498    0.621      0.999
# waiter                     -0.476    0.637      0.999
# shoe.shiner                -0.429    0.670      0.999
# welfare.worker             -0.411    0.683      0.999
# plumber                    -0.378    0.707      0.999
# physician                   0.356    0.724      0.999
# pilot                       0.341    0.735      0.999
# engineer                    0.306    0.761      0.999
# accountant                  0.304    0.763      0.999
# lawyer                     -0.303    0.763      0.999
# undertaker                 -0.187    0.852      0.999
# barber                      0.174    0.863      0.999
# store.manager               0.142    0.887      0.999
# truck.driver               -0.129    0.898      0.999
# cook                        0.127    0.899      0.999
# janitor                    -0.080    0.937      0.999
# policeman                   0.079    0.938      0.999
# architect                   0.072    0.943      0.999
# teacher                     0.051    0.960      0.999
# taxi.driver                 0.023    0.982      0.999
# author                      0.001    0.999      0.999

# %%
rlm_model = rlm('prestige ~ income + education', prestige).fit()
print rlm_model.summary()
# Out:
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:               prestige   No. Observations:                   45
# Model:                            RLM   Df Residuals:                       42
# Method:                          IRLS   Df Model:                            2
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Tue, 17 Jul 2012
# Time:                        10:50:50
# No. Iterations:                    18
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -7.1107      3.879     -1.833      0.067       -14.713     0.492
# income         0.7015      0.109      6.456      0.000         0.489     0.914
# education      0.4854      0.089      5.441      0.000         0.311     0.660
# ==============================================================================
#
# If the model instance has been used for another fit with different fit
# parameters, then the fit options might not be the correct ones anymore .

# %%
print rlm_model.weights
# Out:
# accountant            1.000
# pilot                 1.000
# architect             1.000
# author                1.000
# chemist               1.000
# minister              0.345
# professor             1.000
# dentist               1.000
# reporter              0.442
# engineer              1.000
# undertaker            1.000
# lawyer                1.000
# physician             1.000
# welfare.worker        1.000
# teacher               1.000
# conductor             0.538
# contractor            0.552
# factory.owner         0.706
# store.manager         1.000
# banker                1.000
# bookkeeper            1.000
# mail.carrier          0.691
# insurance.agent       0.533
# store.clerk           0.619
# carpenter             0.936
# electrician           1.000
# RR.engineer           1.000
# machinist             0.570
# auto.repairman        1.000
# plumber               1.000
# gas.stn.attendant     1.000
# coal.miner            0.964
# streetcar.motorman    0.833
# taxi.driver           1.000
# truck.driver          1.000
# machine.operator      1.000
# barber                1.000
# bartender             1.000
# shoe.shiner           1.000
# cook                  1.000
# soda.clerk            1.000
# watchman              1.000
# janitor               1.000
# policeman             1.000
# waiter                1.000

# %% [markdown]
# ### Hertzprung Russell data for Star Cluster CYG 0B1 - Leverage Points

# %% [raw]
# Data is on the luminosity and temperature of 47 stars in the direction of Cygnus.

# %%
try:
    dta = load_data('starsCYG', package='robustbase')
except:
    url = 'eagle1.american.edu/~js2796a/starsCYG.csv'
    dta = pandas.read_csv(url)

# %%
from matplotlib.patches import Ellipse
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, xlabel='log(Temp)', ylabel='log(Light)', title='Hertzsprung-Russell Diagram of Star Cluster CYG OB1')
ax.scatter(*dta.values.T)
# highlight outliers
e = Ellipse((3.5, 6), .2, 1, alpha=.25, color='r')
ax.add_patch(e);
ax.annotate('Red giants', xy=(3.6, 6), xytext=(3.8, 6),
            arrowprops=dict(facecolor='black', shrink=0.05, width=2),
            horizontalalignment='left', verticalalignment='bottom',
            clip_on=True, # clip to the axes bounding box
            fontsize=16,
     )
# annotate these with their index
for i,row in dta.ix[dta['log.Te'] < 3.8].iterrows():
    ax.annotate(i, row, row + .01, fontsize=14)
xlim, ylim = ax.get_xlim(), ax.get_ylim()

# %%
from IPython.display import Image
Image(filename='star_diagram.png')

# %%
y = dta['log.light']
X = sm.add_constant(dta['log.Te'], prepend=True)
ols_model = sm.OLS(y, X).fit()
abline_plot(model_results=ols_model, ax=ax)

# %%
rlm_mod = sm.RLM(y, X, sm.robust.norms.TrimmedMean(.5)).fit()
abline_plot(model_results=rlm_mod, ax=ax, color='red')

# %% [raw]
# Why? Because M-estimators are not robust to leverage points.

# %%
infl = ols_model.get_influence()

# %%
h_bar = 2*(ols_model.df_model + 1 )/ols_model.nobs
hat_diag = infl.summary_frame()['hat_diag']
hat_diag.ix[hat_diag > h_bar]
# Out:
# 11    0.194
# 20    0.194
# 30    0.198
# 34    0.194
# Name: hat_diag

# %%
sidak2 = ols_model.outlier_test('sidak')
sidak2.sort('unadj_p', inplace=True)
# Out:
#     student_resid  unadj_p  sidak(p)
# 17         -2.049    0.046     0.893
# 14         -2.035    0.048     0.900
# 34          1.906    0.063     0.954
# 19         -1.576    0.122     0.998
# 4           1.522    0.135     0.999
# 2           1.522    0.135     0.999
# 22         -1.450    0.154     1.000
# 18         -1.427    0.161     1.000
# 30          1.389    0.172     1.000
# 15         -1.375    0.176     1.000
# 36          1.347    0.185     1.000
# 35         -1.272    0.210     1.000
# 29         -1.187    0.242     1.000
# 21         -1.151    0.256     1.000
# 45          1.135    0.263     1.000
# 40          1.092    0.281     1.000
# 20          1.065    0.293     1.000
# 7          -1.027    0.310     1.000
# 31         -1.009    0.318     1.000
# 23         -0.980    0.333     1.000
# 9           0.961    0.342     1.000
# 6           0.914    0.366     1.000
# 12          0.872    0.388     1.000
# 13          0.857    0.396     1.000
# 47         -0.834    0.409     1.000
# 11          0.744    0.461     1.000
# 43          0.727    0.471     1.000
# 16         -0.689    0.494     1.000
# 44          0.688    0.495     1.000
# 8           0.656    0.515     1.000
# 41         -0.646    0.521     1.000
# 27         -0.641    0.525     1.000
# 26         -0.546    0.588     1.000
# 38          0.473    0.639     1.000
# 33          0.473    0.639     1.000
# 39          0.462    0.646     1.000
# 1           0.431    0.669     1.000
# 32          0.342    0.734     1.000
# 37          0.319    0.751     1.000
# 5           0.308    0.760     1.000
# 10          0.235    0.815     1.000
# 42          0.188    0.852     1.000
# 3          -0.182    0.856     1.000
# 24         -0.156    0.877     1.000
# 28         -0.147    0.883     1.000
# 25          0.065    0.948     1.000
# 46          0.046    0.964     1.000

# %%
fdr2 = ols_model.outlier_test('fdr_bh')
fdr2.sort('unadj_p', inplace=True)
# Out:
#     student_resid  unadj_p  fdr_bh(p)
# 17         -2.049    0.046      0.765
# 14         -2.035    0.048      0.765
# 34          1.906    0.063      0.765
# 19         -1.576    0.122      0.765
# 4           1.522    0.135      0.765
# 2           1.522    0.135      0.765
# 22         -1.450    0.154      0.765
# 18         -1.427    0.161      0.765
# 30          1.389    0.172      0.765
# 15         -1.375    0.176      0.765
# 36          1.347    0.185      0.765
# 35         -1.272    0.210      0.765
# 29         -1.187    0.242      0.765
# 21         -1.151    0.256      0.765
# 45          1.135    0.263      0.765
# 40          1.092    0.281      0.765
# 20          1.065    0.293      0.765
# 7          -1.027    0.310      0.765
# 31         -1.009    0.318      0.765
# 23         -0.980    0.333      0.765
# 9           0.961    0.342      0.765
# 6           0.914    0.366      0.769
# 12          0.872    0.388      0.769
# 13          0.857    0.396      0.769
# 47         -0.834    0.409      0.769
# 11          0.744    0.461      0.771
# 43          0.727    0.471      0.771
# 16         -0.689    0.494      0.771
# 44          0.688    0.495      0.771
# 8           0.656    0.515      0.771
# 41         -0.646    0.521      0.771
# 27         -0.641    0.525      0.771
# 26         -0.546    0.588      0.838
# 38          0.473    0.639      0.844
# 33          0.473    0.639      0.844
# 39          0.462    0.646      0.844
# 1           0.431    0.669      0.850
# 32          0.342    0.734      0.893
# 37          0.319    0.751      0.893
# 5           0.308    0.760      0.893
# 10          0.235    0.815      0.923
# 42          0.188    0.852      0.923
# 3          -0.182    0.856      0.923
# 24         -0.156    0.877      0.923
# 28         -0.147    0.883      0.923
# 25          0.065    0.948      0.964
# 46          0.046    0.964      0.964

# %% [raw]
# Let's delete that line

# %%
del ax.lines[-1]

# %%
weights = np.ones(len(X))
weights[X[X['log.Te'] < 3.8].index.values - 1] = 0
wls_model = sm.WLS(y, X, weights=weights).fit()
abline_plot(model_results=wls_model, ax=ax, color='green')

# %% [raw]
# MM estimators are good for this type of problem, unfortunately, we don't yet have these yet. It's being worked on by one of our Google Summer of Code students. We have a good excuse to look at the R cell magics in the notebook.

# %%
yy = y.values[:,None]
xx = X['log.Te'].values[:,None]

# %%
# %load_ext rmagic

# %Rpush yy xx
# %R mod <- lmrob(yy ~ xx);
# %R params <- mod$coefficients;
# %Rpull params

# %%
# %R print(mod)
# Out:
# Call:
# lmrob(formula = yy ~ xx)
#
# Coefficients:
# (Intercept)           xx
#      -4.969        2.253

# %%
print params
# Out:
# [-4.9694  2.2532]

# %%
abline_plot(intercept=params[0], slope=params[1], ax=ax, color='green')

# %% [markdown]
# ### Exercise: Breakdown points of M-estimator

# %%
np.random.seed(12345)
nobs = 200
beta_true = np.array([3, 1, 2.5, 3, -4])
X = np.random.uniform(-20,20, size=(nobs, len(beta_true)-1))
# stack a constant in front
X = sm.add_constant(X, prepend=True) # np.c_[np.ones(nobs), X]
mc_iter = 500
contaminate = .25 # percentage of response variables to contaminate

# %%
all_betas = []
for i in range(mc_iter):
    y = np.dot(X, beta_true) + np.random.normal(size=200)
    random_idx = np.random.randint(0, nobs, size=int(contaminate * nobs))
    y[random_idx] = np.random.uniform(-750, 750) #, size=len(random_idx))
    beta_hat = sm.RLM(y, X).fit().params
    all_betas.append(beta_hat)

# %%
all_betas = np.asarray(all_betas)
se_loss = lambda x : np.linalg.norm(x, ord=2)**2
se_beta = map(se_loss, all_betas - beta_true)

# %% [markdown]
# #### Squared error loss

# %%
np.array(se_beta).mean()
# Out:
# 0.44502948730686231

# %%
all_betas.mean(0)
# Out:
# array([ 2.9971,  0.999 ,  2.4991,  2.9971, -3.9963])

# %%
beta_true
# Out:
# array([ 3. ,  1. ,  2.5,  3. , -4. ])

# %%
se_loss(all_betas.mean(0) - beta_true)
# Out:
# 3.2360913286757664e-05
